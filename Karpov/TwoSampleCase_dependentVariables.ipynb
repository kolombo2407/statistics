# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
% matplotlib inline

# %%
np.random.seed(123)

# %%
data = pd.read_excel('data/reaction.xls')

# %%
data.head()
# Out:
#    LIGHT  SOUND
# 0    176    168
# 1    163    215
# 2    152    172
# 3    155    200
# 4    156    191

# %%
data.boxplot(figsize=(8,5))
plt.show()

# %%
sample1 = data['SOUND']
sample2 = data['LIGHT']

# %%
from statsmodels.stats.descriptivestats import sign_test

# %%
sign_test(sample1-sample2)
# Out:
# (3.5, 0.06542968749999997)

# %%
plt.figure(figsize=(8,5))
plt.hist(sample1-sample2, bins=5)
plt.show()

# %%
stats.wilcoxon(sample1,sample2)
# Out:
# /Users/evgeny_kolomiets/anaconda3/lib/python3.6/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# WilcoxonResult(statistic=4.5, pvalue=0.011197738894413023)

# %%
stats.wilcoxon(sample1,sample2, alternative='less')
# Out:
# /Users/evgeny_kolomiets/anaconda3/lib/python3.6/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# WilcoxonResult(statistic=61.5, pvalue=0.9944011305527934)

# %%
from statsmodels.graphics.gofplots import qqplot

# %%
qqplot(sample1-sample2, line='s')
plt.show()

# %%
stats.shapiro(sample1-sample2)
# Out:
# ShapiroResult(statistic=0.9517222046852112, pvalue=0.6622841358184814)

# %%
stats.ttest_rel(sample1, sample2)
# Out:
# Ttest_relResult(statistic=3.248672347118036, pvalue=0.007753503906276274)

# %%
np.median(sample1-sample2)
# Out:
# 19.0

# %%
test = np.random.randn(1000)

# %%
stats.shapiro(test)
# Out:
# ShapiroResult(statistic=0.9983539581298828, pvalue=0.46308591961860657)

# %%
stats.jarque_bera(test)
# Out:
# Jarque_beraResult(statistic=1.5723563392313225, pvalue=0.4555826318537535)

# %%
qqplot(test, line='r')
plt.show()

# %%
plt.hist(test, bins=50)
plt.show()
